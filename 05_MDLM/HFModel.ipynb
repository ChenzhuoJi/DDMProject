# %% [markdown]
# <h1> <a href="http://arxiv.org/abs/2406.07524">Simple and Effective Masked Diffusion Language Models</a> by Sahoo et al., 2024 </h1>
#
# This Colab provides a basic demonstration of using an HF model to generate examples from our paper. The model, featuring a context length of `1024`, was trained on the OpenWebText dataset for 1 million training steps, processing approximately `33B` tokens.
#
# **NOTE:** The HF model employed in this Colab does not utilize `Flash Attention`, and all intermediate computations are performed in `fp32` because the T4 GPU on Google Colab does not support Flash Attention.
#
#
#
# 📖 paper: http://arxiv.org/abs/2406.07524
#
# 🏕 code: https://github.com/kuleshov-group/mdlm
#
# 📑 Blog: https://s-sahoo.com/mdlm/
#
# 🤗 Huggingface: https://huggingface.co/kuleshov-group/mdlm-owt

# %% [markdown]
# # Install Dependencies

# %%
# Please ignore any warnings while installing the dependencies
! pip install torch==2.2.1 torchvision==0.17.1 torchaudio==2.2.1 --index-url https://download.pytorch.org/whl/cu121
! pip install datasets
! pip install einops==0.7.0
! pip install fsspec
! pip install git-lfs==1.6
! pip install h5py
! pip install hydra-core==1.3.2
! pip install lightning==2.2.1
! pip install nvitop==1.3.2
! pip install omegaconf==2.3.0
! pip install packaging==23.2
! pip install pandas
! pip install rich==13.7.1
! pip install seaborn==0.13.2
! pip install scikit-learn==1.4.0
! pip install timm==0.9.16
! pip install transformers==4.38.2
! pip install triton
! pip install wandb==0.13.5
! pip install flash-attn==2.5.6

! pip install causal-conv1d==1.1.3.post1
! pip install mamba-ssm==1.1.4
! pip uninstall -y torchao
! pip uninstall -y numpy
! pip install numpy==1.26.4
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Collecting torch==2.2.1
#   Downloading https://download.pytorch.org/whl/cu121/torch-2.2.1%2Bcu121-cp311-cp311-linux_x86_64.whl (757.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.3/757.3 MB 2.5 MB/s eta 0:00:00
# Collecting torchvision==0.17.1
#   Downloading https://download.pytorch.org/whl/cu121/torchvision-0.17.1%2Bcu121-cp311-cp311-linux_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 15.6 MB/s eta 0:00:00
# Collecting torchaudio==2.2.1
#   Downloading https://download.pytorch.org/whl/cu121/torchaudio-2.2.1%2Bcu121-cp311-cp311-linux_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 96.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 52.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 108.3 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.6 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.7 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.6 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 13.1 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.1 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 5.7 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 10.2 MB/s eta 0:00:00
# Collecting triton==2.2.0 (from torch==2.2.1)
#   Downloading https://download.pytorch.org/whl/triton-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.17.1) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.17.1) (11.2.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.2.1) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.2.1) (1.3.0)
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusolver-cu12, nvidia-cudnn-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.21.0+cu124
#     Uninstalling torchvision-0.21.0+cu124:
#       Successfully uninstalled torchvision-0.21.0+cu124
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.6.0+cu124
#     Uninstalling torchaudio-2.6.0+cu124:
#       Successfully uninstalled torchaudio-2.6.0+cu124
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvtx-cu12-12.1.105 torch-2.2.1+cu121 torchaudio-2.2.1+cu121 torchvision-0.17.1+cu121 triton-2.2.0
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (2.14.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec>=2021.11.1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.11.1->datasets) (2025.3.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.31.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Collecting einops==0.7.0
#   Downloading einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: einops
#   Attempting uninstall: einops
#     Found existing installation: einops 0.8.1
#     Uninstalling einops-0.8.1:
#       Successfully uninstalled einops-0.8.1
# Successfully installed einops-0.7.0
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (2025.3.2)
# Collecting git-lfs==1.6
#   Downloading git_lfs-1.6-py2.py3-none-any.whl.metadata (1.2 kB)
# Downloading git_lfs-1.6-py2.py3-none-any.whl (5.6 kB)
# Installing collected packages: git-lfs
# Successfully installed git-lfs-1.6
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (3.13.0)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.11/dist-packages (from h5py) (2.0.2)
# Collecting hydra-core==1.3.2
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.11/dist-packages (from hydra-core==1.3.2) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from hydra-core==1.3.2) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from hydra-core==1.3.2) (24.2)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from omegaconf<2.4,>=2.2->hydra-core==1.3.2) (6.0.2)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: hydra-core
# Successfully installed hydra-core-1.3.2
# Collecting lightning==2.2.1
#   Downloading lightning-2.2.1-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.11/dist-packages (from lightning==2.2.1) (6.0.2)
# Collecting fsspec<2025.0,>=2022.5.0 (from fsspec[http]<2025.0,>=2022.5.0->lightning==2.2.1)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting lightning-utilities<2.0,>=0.8.0 (from lightning==2.2.1)
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: numpy<3.0,>=1.17.2 in /usr/local/lib/python3.11/dist-packages (from lightning==2.2.1) (2.0.2)
# Requirement already satisfied: packaging<25.0,>=20.0 in /usr/local/lib/python3.11/dist-packages (from lightning==2.2.1) (24.2)
# Requirement already satisfied: torch<4.0,>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from lightning==2.2.1) (2.2.1+cu121)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning==2.2.1)
#   Downloading torchmetrics-1.7.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.11/dist-packages (from lightning==2.2.1) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from lightning==2.2.1) (4.13.2)
# Collecting pytorch-lightning (from lightning==2.2.1)
#   Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2025.0,>=2022.5.0->lightning==2.2.1) (3.11.15)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities<2.0,>=0.8.0->lightning==2.2.1) (75.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=1.13.0->lightning==2.2.1) (3.18.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=1.13.0->lightning==2.2.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=1.13.0->lightning==2.2.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=1.13.0->lightning==2.2.1) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=1.13.0->lightning==2.2.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=1.13.0->lightning==2.2.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=1.13.0->lightning==2.2.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=1.13.0->lightning==2.2.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=1.13.0->lightning==2.2.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=1.13.0->lightning==2.2.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=1.13.0->lightning==2.2.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=1.13.0->lightning==2.2.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=1.13.0->lightning==2.2.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=1.13.0->lightning==2.2.1) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=1.13.0->lightning==2.2.1) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=1.13.0->lightning==2.2.1) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<4.0,>=1.13.0->lightning==2.2.1) (12.5.82)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning==2.2.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning==2.2.1) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning==2.2.1) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning==2.2.1) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning==2.2.1) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning==2.2.1) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning==2.2.1) (1.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<4.0,>=1.13.0->lightning==2.2.1) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch<4.0,>=1.13.0->lightning==2.2.1) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning==2.2.1) (3.10)
# Downloading lightning-2.2.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 28.3 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 18.1 MB/s eta 0:00:00
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading torchmetrics-1.7.1-py3-none-any.whl (961 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 kB 63.7 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.1/823.1 kB 62.8 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, fsspec, torchmetrics, pytorch-lightning, lightning
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed fsspec-2024.12.0 lightning-2.2.1 lightning-utilities-0.14.3 pytorch-lightning-2.5.1.post0 torchmetrics-1.7.1
# Collecting nvitop==1.3.2
#   Downloading nvitop-1.3.2-py3-none-any.whl.metadata (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 2.3 MB/s eta 0:00:00
# Collecting nvidia-ml-py<12.536.0a0,>=11.450.51 (from nvitop==1.3.2)
#   Downloading nvidia_ml_py-12.535.161-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.11/dist-packages (from nvitop==1.3.2) (5.9.5)
# Requirement already satisfied: cachetools>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from nvitop==1.3.2) (5.5.2)
# Requirement already satisfied: termcolor>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from nvitop==1.3.2) (3.1.0)
# Downloading nvitop-1.3.2-py3-none-any.whl (215 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.4/215.4 kB 9.8 MB/s eta 0:00:00
# Downloading nvidia_ml_py-12.535.161-py3-none-any.whl (37 kB)
# Installing collected packages: nvidia-ml-py, nvitop
#   Attempting uninstall: nvidia-ml-py
#     Found existing installation: nvidia-ml-py 12.575.51
#     Uninstalling nvidia-ml-py-12.575.51:
#       Successfully uninstalled nvidia-ml-py-12.575.51
# Successfully installed nvidia-ml-py-12.535.161 nvitop-1.3.2
# Requirement already satisfied: omegaconf==2.3.0 in /usr/local/lib/python3.11/dist-packages (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf==2.3.0) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from omegaconf==2.3.0) (6.0.2)
# Collecting packaging==23.2
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: packaging
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# db-dtypes 1.4.3 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# google-cloud-bigquery 3.32.0 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# Successfully installed packaging-23.2
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting rich==13.7.1
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich==13.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich==13.7.1) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich==13.7.1) (0.1.2)
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: rich
#   Attempting uninstall: rich
#     Found existing installation: rich 13.9.4
#     Uninstalling rich-13.9.4:
#       Successfully uninstalled rich-13.9.4
# Successfully installed rich-13.7.1
# Requirement already satisfied: seaborn==0.13.2 in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from seaborn==0.13.2) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn==0.13.2) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn==0.13.2) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (23.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn==0.13.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn==0.13.2) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.17.0)
# Collecting scikit-learn==1.4.0
#   Downloading scikit_learn-1.4.0-1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting numpy<2.0,>=1.19.5 (from scikit-learn==1.4.0)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.4.0) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.4.0) (1.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.4.0) (3.6.0)
# Downloading scikit_learn-1.4.0-1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 95.5 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 70.2 MB/s eta 0:00:00
# Installing collected packages: numpy, scikit-learn
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# db-dtypes 1.4.3 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# Successfully installed numpy-1.26.4 scikit-learn-1.4.0
# Collecting timm==0.9.16
#   Downloading timm-0.9.16-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from timm==0.9.16) (2.2.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from timm==0.9.16) (0.17.1+cu121)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from timm==0.9.16) (6.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from timm==0.9.16) (0.31.2)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from timm==0.9.16) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm==0.9.16) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm==0.9.16) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm==0.9.16) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm==0.9.16) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm==0.9.16) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm==0.9.16) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch->timm==0.9.16) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->timm==0.9.16) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->timm==0.9.16) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->timm==0.9.16) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->timm==0.9.16) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->timm==0.9.16) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.11/dist-packages (from torch->timm==0.9.16) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch->timm==0.9.16) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch->timm==0.9.16) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch->timm==0.9.16) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch->timm==0.9.16) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch->timm==0.9.16) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.11/dist-packages (from torch->timm==0.9.16) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->timm==0.9.16) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->timm==0.9.16) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->timm==0.9.16) (12.5.82)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision->timm==0.9.16) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->timm==0.9.16) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->timm==0.9.16) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->timm==0.9.16) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->timm==0.9.16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->timm==0.9.16) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->timm==0.9.16) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch->timm==0.9.16) (1.3.0)
# Downloading timm-0.9.16-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 29.0 MB/s eta 0:00:00
# Installing collected packages: timm
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.15
#     Uninstalling timm-1.0.15:
#       Successfully uninstalled timm-1.0.15
# Successfully installed timm-0.9.16
# Collecting transformers==4.38.2
#   Downloading transformers-4.38.2-py3-none-any.whl.metadata (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.7/130.7 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.38.2) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.11/dist-packages (from transformers==4.38.2) (0.31.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.38.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.38.2) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.38.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.38.2) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.38.2) (2.32.3)
# Collecting tokenizers<0.19,>=0.14 (from transformers==4.38.2)
#   Downloading tokenizers-0.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.38.2) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.38.2) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.2) (2024.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.2) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.38.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.38.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.38.2) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.38.2) (2025.4.26)
# Downloading transformers-4.38.2-py3-none-any.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 78.7 MB/s eta 0:00:00
# Downloading tokenizers-0.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 98.7 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.51.3
#     Uninstalling transformers-4.51.3:
#       Successfully uninstalled transformers-4.51.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.38.2 which is incompatible.
# Successfully installed tokenizers-0.15.2 transformers-4.38.2
# Requirement already satisfied: triton in /usr/local/lib/python3.11/dist-packages (2.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from triton) (3.18.0)
# Collecting wandb==0.13.5
#   Downloading wandb-0.13.5-py2.py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.11/dist-packages (from wandb==0.13.5) (8.2.0)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb==0.13.5) (3.1.44)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb==0.13.5) (2.32.3)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from wandb==0.13.5) (2.3)
# Collecting shortuuid>=0.5.0 (from wandb==0.13.5)
#   Downloading shortuuid-1.0.13-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb==0.13.5) (5.9.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb==0.13.5) (2.28.0)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from wandb==0.13.5) (1.17.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb==0.13.5) (0.4.0)
# Collecting protobuf!=4.0.*,!=4.21.0,<5,>=3.12.0 (from wandb==0.13.5)
#   Downloading protobuf-4.25.7-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from wandb==0.13.5) (6.0.2)
# Collecting pathtools (from wandb==0.13.5)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb==0.13.5) (1.3.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb==0.13.5) (75.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from GitPython>=1.0.0->wandb==0.13.5) (4.0.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb==0.13.5) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb==0.13.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb==0.13.5) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb==0.13.5) (2025.4.26)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb==0.13.5) (5.0.2)
# Downloading wandb-0.13.5-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 21.3 MB/s eta 0:00:00
# Downloading protobuf-4.25.7-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 26.8 MB/s eta 0:00:00
# Downloading shortuuid-1.0.13-py3-none-any.whl (10 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8792 sha256=4d574393a4283188f5837e0ca3550ceecfaeb07c9ea6ae48a1fb1e4c80f2858a
#   Stored in directory: /root/.cache/pip/wheels/ea/b7/8b/84e94095ea418b9442f5abeba4ca7b0ad52d3fe7b69d6238a6
# Successfully built pathtools
# Installing collected packages: pathtools, shortuuid, protobuf, wandb
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Uninstalling protobuf-5.29.4:
#       Successfully uninstalled protobuf-5.29.4
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.19.11
#     Uninstalling wandb-0.19.11:
#       Successfully uninstalled wandb-0.19.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydf 0.11.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.7 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.7 which is incompatible.
# Successfully installed pathtools-0.1.2 protobuf-4.25.7 shortuuid-1.0.13 wandb-0.13.5
# Collecting flash-attn==2.5.6
#   Downloading flash_attn-2.5.6.tar.gz (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 25.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from flash-attn==2.5.6) (2.2.1+cu121)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from flash-attn==2.5.6) (0.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from flash-attn==2.5.6) (23.2)
# Collecting ninja (from flash-attn==2.5.6)
#   Downloading ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.5.6) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.5.6) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.5.6) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.5.6) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.5.6) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.5.6) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.5.6) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.5.6) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.5.6) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.5.6) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.5.6) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.5.6) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.5.6) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.5.6) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.5.6) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.5.6) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.5.6) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.5.6) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->flash-attn==2.5.6) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->flash-attn==2.5.6) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch->flash-attn==2.5.6) (1.3.0)
# Downloading ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (422 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 31.1 MB/s eta 0:00:00
# Building wheels for collected packages: flash-attn
#   Building wheel for flash-attn (setup.py) ... done
#   Created wheel for flash-attn: filename=flash_attn-2.5.6-cp311-cp311-linux_x86_64.whl size=120611965 sha256=850b283dab9f2ca044f6537d51dadb481611377d5347e7be4521d7b9bf271206
#   Stored in directory: /root/.cache/pip/wheels/a1/60/7e/444e85ea67585255dd376ceb55c8434526ca192042f80402d2
# Successfully built flash-attn
# Installing collected packages: ninja, flash-attn
# Successfully installed flash-attn-2.5.6 ninja-1.11.1.4
# Collecting causal-conv1d==1.1.3.post1
#   Downloading causal_conv1d-1.1.3.post1.tar.gz (6.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from causal-conv1d==1.1.3.post1) (2.2.1+cu121)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from causal-conv1d==1.1.3.post1) (23.2)
# Collecting buildtools (from causal-conv1d==1.1.3.post1)
#   Downloading buildtools-1.0.6.tar.gz (446 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.5/446.5 kB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->causal-conv1d==1.1.3.post1) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->causal-conv1d==1.1.3.post1) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->causal-conv1d==1.1.3.post1) (12.5.82)
# Requirement already satisfied: six>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from furl->buildtools->causal-conv1d==1.1.3.post1) (1.17.0)
# Collecting orderedmultidict>=1.0.1 (from furl->buildtools->causal-conv1d==1.1.3.post1)
#   Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->buildtools->causal-conv1d==1.1.3.post1) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->buildtools->causal-conv1d==1.1.3.post1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->buildtools->causal-conv1d==1.1.3.post1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->buildtools->causal-conv1d==1.1.3.post1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->buildtools->causal-conv1d==1.1.3.post1) (2025.4.26)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy->buildtools->causal-conv1d==1.1.3.post1) (3.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch->causal-conv1d==1.1.3.post1) (1.3.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from twisted->buildtools->causal-conv1d==1.1.3.post1) (25.3.0)
# Collecting automat>=24.8.0 (from twisted->buildtools->causal-conv1d==1.1.3.post1)
#   Downloading automat-25.4.16-py3-none-any.whl.metadata (8.4 kB)
# Collecting constantly>=15.1 (from twisted->buildtools->causal-conv1d==1.1.3.post1)
#   Downloading constantly-23.10.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting hyperlink>=17.1.1 (from twisted->buildtools->causal-conv1d==1.1.3.post1)
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting incremental>=24.7.0 (from twisted->buildtools->causal-conv1d==1.1.3.post1)
#   Downloading incremental-24.7.2-py3-none-any.whl.metadata (8.1 kB)
# Collecting zope-interface>=5 (from twisted->buildtools->causal-conv1d==1.1.3.post1)
#   Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=61.0 in /usr/local/lib/python3.11/dist-packages (from incremental>=24.7.0->twisted->buildtools->causal-conv1d==1.1.3.post1) (75.2.0)
# Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Downloading furl-2.1.4-py2.py3-none-any.whl (27 kB)
# Downloading redo-3.0.0-py2.py3-none-any.whl (14 kB)
# Downloading twisted-24.11.0-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 65.3 MB/s eta 0:00:00
# Downloading automat-25.4.16-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 4.3 MB/s eta 0:00:00
# Downloading constantly-23.10.4-py3-none-any.whl (13 kB)
# Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 8.4 MB/s eta 0:00:00
# Downloading incremental-24.7.2-py3-none-any.whl (20 kB)
# Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl (11 kB)
# Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 24.3 MB/s eta 0:00:00
# Building wheels for collected packages: causal-conv1d, buildtools, docopt
#   Building wheel for causal-conv1d (setup.py) ... done
#   Created wheel for causal-conv1d: filename=causal_conv1d-1.1.3.post1-cp311-cp311-linux_x86_64.whl size=13928463 sha256=9e8866d56289fba14a9317ec300140019a048e9c65410236d47d586a34620fe6
#   Stored in directory: /root/.cache/pip/wheels/be/55/92/2c965213172b948641606c659991612d9f401de7f278840f04
#   Building wheel for buildtools (setup.py) ... done
#   Created wheel for buildtools: filename=buildtools-1.0.6-py3-none-any.whl size=512342 sha256=2ad71a0a7c627655df531f4cfac1149a75796d652de1086729b98226844ac2ca
#   Stored in directory: /root/.cache/pip/wheels/08/ee/fa/4351d8eba6a57dadf762795886f1b5a607311fe493cdc955f4
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=2d3ede0724403f49ee3146de566f51b53933021776e48b3a42dcf8be7b85e99e
#   Stored in directory: /root/.cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built causal-conv1d buildtools docopt
# Installing collected packages: redo, docopt, argparse, zope-interface, orderedmultidict, incremental, hyperlink, constantly, automat, twisted, furl, buildtools, causal-conv1d
# Successfully installed argparse-1.4.0 automat-25.4.16 buildtools-1.0.6 causal-conv1d-1.1.3.post1 constantly-23.10.4 docopt-0.6.2 furl-2.1.4 hyperlink-21.0.0 incremental-24.7.2 orderedmultidict-1.0.1 redo-3.0.0 twisted-24.11.0 zope-interface-7.2
# Collecting mamba-ssm==1.1.4
#   Downloading mamba_ssm-1.1.4.tar.gz (34 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from mamba-ssm==1.1.4) (2.2.1+cu121)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mamba-ssm==1.1.4) (23.2)
# Requirement already satisfied: ninja in /usr/local/lib/python3.11/dist-packages (from mamba-ssm==1.1.4) (1.11.1.4)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from mamba-ssm==1.1.4) (0.7.0)
# Requirement already satisfied: triton in /usr/local/lib/python3.11/dist-packages (from mamba-ssm==1.1.4) (2.2.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from mamba-ssm==1.1.4) (4.38.2)
# Requirement already satisfied: causal_conv1d<1.2.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from mamba-ssm==1.1.4) (1.1.3.post1)
# Requirement already satisfied: buildtools in /usr/local/lib/python3.11/dist-packages (from causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4) (1.0.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->mamba-ssm==1.1.4) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch->mamba-ssm==1.1.4) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch->mamba-ssm==1.1.4) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->mamba-ssm==1.1.4) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->mamba-ssm==1.1.4) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->mamba-ssm==1.1.4) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->mamba-ssm==1.1.4) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->mamba-ssm==1.1.4) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->mamba-ssm==1.1.4) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.11/dist-packages (from torch->mamba-ssm==1.1.4) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch->mamba-ssm==1.1.4) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch->mamba-ssm==1.1.4) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch->mamba-ssm==1.1.4) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch->mamba-ssm==1.1.4) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch->mamba-ssm==1.1.4) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.11/dist-packages (from torch->mamba-ssm==1.1.4) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->mamba-ssm==1.1.4) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->mamba-ssm==1.1.4) (12.5.82)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.11/dist-packages (from transformers->mamba-ssm==1.1.4) (0.31.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers->mamba-ssm==1.1.4) (1.26.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers->mamba-ssm==1.1.4) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->mamba-ssm==1.1.4) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers->mamba-ssm==1.1.4) (2.32.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.11/dist-packages (from transformers->mamba-ssm==1.1.4) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers->mamba-ssm==1.1.4) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers->mamba-ssm==1.1.4) (4.67.1)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.11/dist-packages (from buildtools->causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4) (2.0.40)
# Collecting argparse (from buildtools->causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: twisted in /usr/local/lib/python3.11/dist-packages (from buildtools->causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4) (24.11.0)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.11/dist-packages (from buildtools->causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4) (3.20.1)
# Requirement already satisfied: furl in /usr/local/lib/python3.11/dist-packages (from buildtools->causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4) (2.1.4)
# Requirement already satisfied: docopt in /usr/local/lib/python3.11/dist-packages (from buildtools->causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4) (0.6.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from buildtools->causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4) (2.9.0.post0)
# Requirement already satisfied: redo in /usr/local/lib/python3.11/dist-packages (from buildtools->causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->mamba-ssm==1.1.4) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->mamba-ssm==1.1.4) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->mamba-ssm==1.1.4) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->mamba-ssm==1.1.4) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->mamba-ssm==1.1.4) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch->mamba-ssm==1.1.4) (1.3.0)
# Requirement already satisfied: six>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from furl->buildtools->causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4) (1.17.0)
# Requirement already satisfied: orderedmultidict>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from furl->buildtools->causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4) (1.0.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy->buildtools->causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4) (3.2.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from twisted->buildtools->causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4) (25.3.0)
# Requirement already satisfied: automat>=24.8.0 in /usr/local/lib/python3.11/dist-packages (from twisted->buildtools->causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4) (25.4.16)
# Requirement already satisfied: constantly>=15.1 in /usr/local/lib/python3.11/dist-packages (from twisted->buildtools->causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in /usr/local/lib/python3.11/dist-packages (from twisted->buildtools->causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in /usr/local/lib/python3.11/dist-packages (from twisted->buildtools->causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4) (24.7.2)
# Requirement already satisfied: zope-interface>=5 in /usr/local/lib/python3.11/dist-packages (from twisted->buildtools->causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4) (7.2)
# Requirement already satisfied: setuptools>=61.0 in /usr/local/lib/python3.11/dist-packages (from incremental>=24.7.0->twisted->buildtools->causal_conv1d<1.2.0,>=1.1.0->mamba-ssm==1.1.4) (75.2.0)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Building wheels for collected packages: mamba-ssm
#   Building wheel for mamba-ssm (setup.py) ... done
#   Created wheel for mamba-ssm: filename=mamba_ssm-1.1.4-cp311-cp311-linux_x86_64.whl size=137763145 sha256=26a4f54764b6baa4a1da0007af6c754bff497ca0e0d26f6111f14aa00e1a5dbb
#   Stored in directory: /root/.cache/pip/wheels/8a/b2/a3/3f3a9a59d8ca43c6bcc1766dc1f63e1d3436c73540b59397bf
# Successfully built mamba-ssm
# Installing collected packages: argparse, mamba-ssm
# Successfully installed argparse-1.4.0 mamba-ssm-1.1.4
# Found existing installation: torchao 0.10.0
# Uninstalling torchao-0.10.0:
#   Successfully uninstalled torchao-0.10.0
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# db-dtypes 1.4.3 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.38.2 which is incompatible.
# ydf 0.11.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.7 which is incompatible.
# Successfully installed numpy-1.26.4

# %% [markdown]
# # Git clone

# %%
! git clone https://github.com/kuleshov-group/mdlm.git
# Out:
# Cloning into 'mdlm'...
# remote: Enumerating objects: 175, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 175 (delta 43), reused 35 (delta 34), pack-reused 115 (from 1)
# Receiving objects: 100% (175/175), 107.41 KiB | 2.68 MiB/s, done.
# Resolving deltas: 100% (76/76), done.

# %% [markdown]
# # Imports

# %%
import os
os.chdir('mdlm')

import fsspec
import hydra
import lightning as L
import numpy as np
if np.__version__ != '1.26.4':
  # After installing the above packages, the correct NumPy version may not be
  # loaded. To fix this, we must restart the session and re-run this cell.
  # After restarting, there's no need to run the prior cell with pip installs.
  os.kill(os.getpid(), 9)
import omegaconf
import rich.syntax
import rich.tree
import torch

import dataloader
import diffusion
import main
import utils

# %% [markdown]
# # Sample generation

# %%
overrides=['mode=sample_eval',
           'eval.checkpoint_path=kuleshov-group/mdlm-no_flashattn-fp32-owt',
           'data=openwebtext-split',
           'model.length=1024',
           'sampling.predictor=ddpm_cache',
           'sampling.steps=1000',
           'loader.eval_batch_size=1',
           'sampling.num_sample_batches=1',
           'backbone=hf_dit']

with hydra.initialize(version_base=None,
                      config_path='configs'):
  config = hydra.compose(config_name='config', overrides=overrides)
  sar_config = hydra.compose(config_name='config', overrides=overrides)

# %%
L.seed_everything(config.seed)

logger = utils.get_logger(__name__)
tokenizer = dataloader.get_tokenizer(config)

samples = main.generate_samples(config, logger, tokenizer)
for sample in samples:
  print(sample)
# Out:
# INFO: Seed set to 1
# INFO:lightning.fabric.utilities.seed:Seed set to 1
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# INFO:__main__:Generating samples.
# config.json:   0%|          | 0.00/509 [00:00<?, ?B/s]
# configuration_mdlm.py:   0%|          | 0.00/740 [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/kuleshov-group/mdlm-no_flashattn-fp32-owt:
# - configuration_mdlm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_mdlm_2.py:   0%|          | 0.00/14.5k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/kuleshov-group/mdlm-no_flashattn-fp32-owt:
# - modeling_mdlm_2.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/679M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Text samples: ['<|endoftext|> do something else and then just work on yourself. You give them a lot of time. So it’s quicker.\n\nKO: You’ve been placed there and there’s been the work there already: working on your game; working on effort; working on progress. How does that feel to be around?\n\nBODYBOARD GETHER: It does give everybody a job to keep spending their time in the game, working on everything. And doing stuff better is just getting around to contributions already made.\n\nRANDON WILLIGAN: There are a lot of stars in the game who have a little bit more experience in South Australia. How was it like to have that?\n\nJOSEL LA PASCO: It was a huge difference. So much for my age group, you were never going to play here in Adelaide, which I did because I wasn’t offer a contract, pretty much everything.\n\nIn my third year I didn’t earn a home contract for that. I had a lot of time overseas, varying in the skills and competitions, in the smaller league, but I had so much further time at home. That, yeah. That was tough. But then I got to Adelaide and it was really good for me.\n\nI think it’s like 2013. But it’s been a long time after, so if there was anything generally at the same pretty young age as I entered Origin kicked football team, it was 2008.\n\nThat difference was made so quick. I know I’m still too young. You have so much experience that you wouldn’t have felt comfortable at just a couple of months. Why didn’t I’m in Origin ball for such an age? And then because Origin games take so long, you know why I would be making that group of mistakes. So much changing though, so much coming out.\n\nI’m looking forward to stepping into the two next. I’m just not as good at the three impas, So many more and getting caught up with them – getting kicked out of situations as well as dropping three scores.\n\nBut you also have the same response for the first time, so I realise that I’m gonna need more to do. And that probably kind of helped me in Adelaide.\n\nI did so much better work with one foot on the front but I could do better with my other foot on the other side.\n\nKO: Josao LADA, that’s what the hamstring was.\n\nJOSEL MILL: I knew I needed something better. I would run the last seven, eight metres, but that part I couldn’t have been as bad in as that.\n\nLILA FARA: I actually pulled the weight very good.\n\nJOSDO LADA: Incredible.\n\nKO: Kiko Thompson took around 200 metres to start pushing it.\n\nReally?\n\nKO: Yeah, full 300 metres which was 4.5 metres, 5.5 metres. Six good lifts.\n\nKO: What was your best training work?\n\nJOSEL PASCO: That one I wouldn’t want to answer. It was my worst. Look, in front of me, I’m too big a head like that and I can play hands like that here, a really good hand – but also been hard, I would say, with my wrists, with consequent hip tension.\n\nJONIS DAVO: Wow. It was a good first start. Also, not the kind of guy I ever played a lot for the New South Wales side. I’m round straight away he was competing, to be so hot in that area.\n\nMITTIAN: To be so hot at A’s, that was extremely good.\n\nKO: I’ve, I think Chris Taylor said something about the wear in the boots.\n\nLUIS EBIBSTER: I’ve had a bigger day before.\n\nORMIA: Better sick than nothing, mate.\n\nKO: We both went with those boots.\n\nNAHBSON: I love the regular boot.\n\nKO: I have been really racing lot with my boot.\n\nORMIA: It takes a bit of time. And some force in the body maybe a little bit.\n\nEveryone has had some good thoughts on boots though. Maybe you have older and wiser players, believe me, use the boot, and it really enables them to continue.\n\nIRERO PANASIO: I’ve had players, every NRL player when they used the boots, say, “If you keep using the shoes there’ll be longevity and they can go on that”. There’s an element of respect for those, but no.<|endoftext|>']
# Generative perplexity: tensor(34.3114, device='cuda:0')
# <|endoftext|> do something else and then just work on yourself. You give them a lot of time. So it’s quicker.
#
# KO: You’ve been placed there and there’s been the work there already: working on your game; working on effort; working on progress. How does that feel to be around?
#
# BODYBOARD GETHER: It does give everybody a job to keep spending their time in the game, working on everything. And doing stuff better is just getting around to contributions already made.
#
# RANDON WILLIGAN: There are a lot of stars in the game who have a little bit more experience in South Australia. How was it like to have that?
#
# JOSEL LA PASCO: It was a huge difference. So much for my age group, you were never going to play here in Adelaide, which I did because I wasn’t offer a contract, pretty much everything.
#
# In my third year I didn’t earn a home contract for that. I had a lot of time overseas, varying in the skills and competitions, in the smaller league, but I had so much further time at home. That, yeah. That was tough. But then I got to Adelaide and it was really good for me.
#
# I think it’s like 2013. But it’s been a long time after, so if there was anything generally at the same pretty young age as I entered Origin kicked football team, it was 2008.
#
# That difference was made so quick. I know I’m still too young. You have so much experience that you wouldn’t have felt comfortable at just a couple of months. Why didn’t I’m in Origin ball for such an age? And then because Origin games take so long, you know why I would be making that group of mistakes. So much changing though, so much coming out.
#
# I’m looking forward to stepping into the two next. I’m just not as good at the three impas, So many more and getting caught up with them – getting kicked out of situations as well as dropping three scores.
#
# But you also have the same response for the first time, so I realise that I’m gonna need more to do. And that probably kind of helped me in Adelaide.
#
# I did so much better work with one foot on the front but I could do better with my other foot on the other side.
#
# KO: Josao LADA, that’s what the hamstring was.
#
# JOSEL MILL: I knew I needed something better. I would run the last seven, eight metres, but that part I couldn’t have been as bad in as that.
#
# LILA FARA: I actually pulled the weight very good.
#
# JOSDO LADA: Incredible.
#
# KO: Kiko Thompson took around 200 metres to start pushing it.
#
# Really?
#
# KO: Yeah, full 300 metres which was 4.5 metres, 5.5 metres. Six good lifts.
#
# KO: What was your best training work?
#
# JOSEL PASCO: That one I wouldn’t want to answer. It was my worst. Look, in front of me, I’m too big a head like that and I can play hands like that here, a really good hand – but also been hard, I would say, with my wrists, with consequent hip tension.
#
# JONIS DAVO: Wow. It was a good first start. Also, not the kind of guy I ever played a lot for the New South Wales side. I’m round straight away he was competing, to be so hot in that area.
#
# MITTIAN: To be so hot at A’s, that was extremely good.
#
# KO: I’ve, I think Chris Taylor said something about the wear in the boots.
#
# LUIS EBIBSTER: I’ve had a bigger day before.
#
# ORMIA: Better sick than nothing, mate.
#
# KO: We both went with those boots.
#
# NAHBSON: I love the regular boot.
#
# KO: I have been really racing lot with my boot.
#
# ORMIA: It takes a bit of time. And some force in the body maybe a little bit.
#
# Everyone has had some good thoughts on boots though. Maybe you have older and wiser players, believe me, use the boot, and it really enables them to continue.
#
# IRERO PANASIO: I’ve had players, every NRL player when they used the boots, say, “If you keep using the shoes there’ll be longevity and they can go on that”. There’s an element of respect for those, but no.<|endoftext|>

# %% [markdown]
# ## Semi Autoregressive sample generation

# %%
sar_config['sampling']['semi_ar'] = True
sar_config['sampling']['stride_length'] = 512
sar_config['sampling']['num_strides'] = 2

# Generates conext_length + num_strides * stride_length number of tokens.
# In this case we generate 1024 + 2 * 512 = 2048 tokens.

samples = main.generate_samples(sar_config, logger, tokenizer)
for sample in samples:
  print(sample)
# Out:
# INFO:__main__:Generating samples.
# Text samples: ["<|endoftext|>, but some leave questions as how it relates to the different types of cancers.\n\nWhat are the first hints of a mutation that leads to cancer in humans?\n\nLike just about everyone, science has cheered in recent years in some rather fascinating natural cell biology studies on a genome. But are there necessarily deep challenges behind these findings that are entirely unexpected? Yes, there is evidence this gene was linked to either the process of aging, or cancer – and researchers are looking for answers underlying these processes.\n\nThis study could have linked DNA in cycles for about 20 years. ‘Discovering knowledge about how DNA is occurring between chromosomes in our cells has allowed us to use worms, pigs, and microbes to work in this host biological environment,’ says Karina Sodgaard, a research scientist at the University of European Systems.\n\nAs the University of Melbourne had been test this effect for a window of 10 years, their first tests raised many questions: how genetics caused different types of cancer. Our genes may be the result of an amount of genetic teaching known as ‘cancer mastery’ they have shown. May DNA machines are responsible for these effects? The big answer seems to be that cancer can spread about because of how many mutations you have making it, and it will often flow from a rare one. The tricky part is that solving previously elusive tests like predicting how inheritance relates to cancer appears to be a centuries-old problem, and we don’t really know yet which DNA mutation caused us.\n\nThe last step in the long-running genetic mystery is to see how the genes take in\n\nScientists may have even uncovered more rare mutations in cancers, suggesting that these mutations come either in parts of innate alterations, perhaps the reason some have such rapid expansion of breast development. There are clues that this is connected to common genetic causes: breast and ovarian cancer, diabetes, cancer, and kidney disease are the causes, as are many.\n\nIt’s that large an idea now, looking at how these evolutionary influences on two differently known cancers – the researchers show that altered germ genes contribute to lots more. They are working on the answer to that, which is only the first step.\n\nHerman, and her team from Pencille in the UK, in Bethesda, and others in New York, try different versions of a set of tests by linking chromosome mutations in various types. After being reassured that certain traits bounce back, it’s time for a little work on the other forms. They were shown to perform ‘elimination times small to nothing in reality’ tests. But most importantly, they looked at whether DNA mutations resulting from different forms of age and gender may lead to mutations that perhaps carry large genetic significance in homeopathy. And it also might play a deep role in cancer.\n\nClearly not all DNA mutations are being passed back on in cancer cells\n\nThis hasn’t worked yet. Herman and colleagues studied more than 1,000 sex chromosomes for 12 years between 1998 and 2004, and found that 98% of cancers disappeared when they were first linked to breast, prostate, or scar tissue. But just last week, a Scottish lab in the University of Glasgow, working with Jenssen and colleagues in men’s trials, found that if the women had no genetic alterations, the breast mutation was being recur in the same weeks as a mutation in DNA. A mutation in males was being passed on only at the time of the cancer.\n\n“The research is getting increasingly validating\n\nThe researchers have conducted another possible experiment, at work at the University of Melbourne in the US and UK. That project’s results, which are on peer-reviewed.org this year, found that there seemed to have been another genetic effect (although they underestimated the dose) as any.\n\nIt was an example of how the same proteins appear in humans. Again, the DNA behaves much differently than mammals, meaning it is only accumul ...
# <|endoftext|>, but some leave questions as how it relates to the different types of cancers.
#
# What are the first hints of a mutation that leads to cancer in humans?
#
# Like just about everyone, science has cheered in recent years in some rather fascinating natural cell biology studies on a genome. But are there necessarily deep challenges behind these findings that are entirely unexpected? Yes, there is evidence this gene was linked to either the process of aging, or cancer – and researchers are looking for answers underlying these processes.
#
# This study could have linked DNA in cycles for about 20 years. ‘Discovering knowledge about how DNA is occurring between chromosomes in our cells has allowed us to use worms, pigs, and microbes to work in this host biological environment,’ says Karina Sodgaard, a research scientist at the University of European Systems.
#
# As the University of Melbourne had been test this effect for a window of 10 years, their first tests raised many questions: how genetics caused different types of cancer. Our genes may be the result of an amount of genetic teaching known as ‘cancer mastery’ they have shown. May DNA machines are responsible for these effects? The big answer seems to be that cancer can spread about because of how many mutations you have making it, and it will often flow from a rare one. The tricky part is that solving previously elusive tests like predicting how inheritance relates to cancer appears to be a centuries-old problem, and we don’t really know yet which DNA mutation caused us.
#
# The last step in the long-running genetic mystery is to see how the genes take in
#
# Scientists may have even uncovered more rare mutations in cancers, suggesting that these mutations come either in parts of innate alterations, perhaps the reason some have such rapid expansion of breast development. There are clues that this is connected to common genetic causes: breast and ovarian cancer, diabetes, cancer, and kidney disease are the causes, as are many.
#
# It’s that large an idea now, looking at how these evolutionary influences on two differently known cancers – the researchers show that altered germ genes contribute to lots more. They are working on the answer to that, which is only the first step.
#
# Herman, and her team from Pencille in the UK, in Bethesda, and others in New York, try different versions of a set of tests by linking chromosome mutations in various types. After being reassured that certain traits bounce back, it’s time for a little work on the other forms. They were shown to perform ‘elimination times small to nothing in reality’ tests. But most importantly, they looked at whether DNA mutations resulting from different forms of age and gender may lead to mutations that perhaps carry large genetic significance in homeopathy. And it also might play a deep role in cancer.
#
# Clearly not all DNA mutations are being passed back on in cancer cells
#
# This hasn’t worked yet. Herman and colleagues studied more than 1,000 sex chromosomes for 12 years between 1998 and 2004, and found that 98% of cancers disappeared when they were first linked to breast, prostate, or scar tissue. But just last week, a Scottish lab in the University of Glasgow, working with Jenssen and colleagues in men’s trials, found that if the women had no genetic alterations, the breast mutation was being recur in the same weeks as a mutation in DNA. A mutation in males was being passed on only at the time of the cancer.
#
# “The research is getting increasingly validating
#
# The researchers have conducted another possible experiment, at work at the University of Melbourne in the US and UK. That project’s results, which are on peer-reviewed.org this year, found that there seemed to have been another genetic effect (although they underestimated the dose) as any.
#
# It was an example of how the same proteins appear in humans. Again, the DNA behaves much differently than mammals, meaning it is only accumulating trouble, three times slower than chimpanzees did. Over the next decade, the team has thought 13 times number of mutations and those mutations in helix – the DNA that reproduce human DNA — roll off to the nucleus of an egg. (Headlines in the 1970s: ‘we are now being checking these genes by arranging identical-looking samples of DNA or genes’.) most important yet is that the researchers seem to have studied the same mutation in mice. They have concluded that, even though eggs produce the mutation, the DNA did not get affected – the DNA it is in is completely different.
#
# The egg mutation may have happened in the mouse egg itself, not the DNA.
# Peter Jens-Gyllensen, an Imperial College London professor and of the scientists, says some of the genetic errors were made in the egg half a planet away, as well as other issues in the laboratory where the DNA mutations originated. These labs, says Peter Jens-Jensen do not understand why these eggs are mutated at<|endoftext|>It’s getting going with apps and new applications natively ramp up the adoption of mobile websites. Companies have so far made a lot of changes to the way people view mobile content in this space, but it’s not one of them surprising: Google continued to introduce their browser and rely almost exclusively on it on their devices, Apple is selling a web browser that in some is tailored specifically to consumers and Samsung is doing the same thanks to their Chrome web browser. For these different content, from photos vs, video, to different ad placements, the new model is that each company offers a little different how users are having direct business with type of content, all helping to make the clearer and more usable.
#
# Since most of these updates are about the technical details, it’s a challenge to think about yourself whether apps run on your iOS devices or not.
#
# Today’s change is about trying to get companies like Apple to accept the way that people use content which is specifically designed to make it into something you are using without walking around blindly loving what is not. You can be sure that third-party apps that are yours by no more than part of your company will end up running through your devices or waiting for your real-party app to reply to your notification.
#
# Advertisement
#
# However, this does not apply to Apple customers. There have been a conundrum of sorts users on iOS have been asked to deal with: some of their apps already run the same page as third party apps from iOS but that you don’t know which apps should run them even if some of them shouldn’t be on your web page; well as telling them that the app does this for you and not deploying a huge error without having a (real) attachable page, or telling them to make a statement to them that won’t immediately appear with the correct fix (”remessage@w).
#
# In addition to that, especially to third-party apps, says Apple, the problem isn’t users accidentally make a big mistake in their apps, or while their web pages or just changing them for a one iPhone app: “People who may have thought their app came down when they were preparing HTML and maybe they should use or edit it but they didn’t make a big mistake.” It does show itself here.
#
# Just without also knowing why different apps might behave differently than respond to messages or emails to a particular user point by point: Samsung<|endoftext|>So I think it’s pretty fair to start with a world-wide event that's impacted both in the world – what it might, of course, not be like if in a room this What happens? 60% of gamers wouldn't want games played first, when all, they'd be put on line to make sure they get feedback happy not playing game first – Put it on a portion of a plane so where? on your desktop you perhaps? on your console. How? Data on data on contents of an internet exchange – a fuller read of the text, along with% of your brain whether things and where the data is stored and the category of this it is placed in.
#
# So up to? Data’s in that you’re monitoring your brain as a whole… and you know: you better interpret how to it and therefore make it better. So, you make it a better place by taking data that your brain deems to be relevant?
#
# But necessarily inaccurate or inaccurate, there are contrary those in the way we think. And then we still rely on until something bad doesn’t necessarily hit the way your brain looks – the science that judgement is based. And the world-wide live service is excellent, you always get answers to problems in all fields. But, as a personal possession, many of us think 80% of our head consists of totality, of everything we reflect and 100% is comprised of what we don’t. If you try to get done at the last minute where is it and your brain is working when they’re happening? And what about it? And how do you do it everyday while they’re happening? Finding a working bug for this kind of stuff. It’s how many of us think it’s good: old friend Randi Katars had it started by installing the party software, and installing the thing an on-campus computer in his company's offices and data centre. He read an on-disk data, had to get it in the running, after which his company’s IT department could an up on the issue. That might involve a distributed effort. And as he got first-hand-hand examples of his problems a ‘big name ’ hadn’t been able to do this. But he was able to get some involved in his real-world collaboration some time and time. And that's why it's so interesting to me and it’s fascinating how these biases blind us and
